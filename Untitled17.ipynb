# %% [markdown]
# <a href="https://colab.research.google.com/github/kanjamwingirwa/Olist/blob/kanja/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Begin by importing the necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
import datetime as dt
import warnings
warnings. filterwarnings("ignore")

# %% [markdown]
# Read and preview your respective data sets

# %%
category_translation_df = pd.read_csv('/content/olist_products_dataset.csv')
category_translation_df.head(5)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
customer_df = pd.read_csv('/content/olist_customers_dataset.csv')
customer_df.head(5)
# Out:
#                         customer_id                customer_unique_id  \
# 0  06b8999e2fba1a1fbc88172c00ba8bc7  861eff4711a542e4b93843c6dd7febb0
# 1  18955e83d337fd6b2def6b18a428ac77  290c77bc529b7ac935b93aa66c333dc3
# 2  4e7b3e00288586ebd08712fdd0374a03  060e732b5b29e8181a18229c7b0b2b5e
# 3  b2b6027bc5c5109e529d4dc6358b12c3  259dac757896d24d7702b9acbbff3f3c
# 4  4f2d8ab171c80ec8364f7c12e35b23ad  345ecd01c38d18a9036ed96c73b8d066
#
#    customer_zip_code_prefix          customer_city customer_state
# 0                     14409                 franca             SP
# 1                      9790  sao bernardo do campo             SP
# 2                      1151              sao paulo             SP
# 3                      8775        mogi das cruzes             SP
# 4                     13056               campinas             SP

# %%
geolocation_df = pd.read_csv('/content/olist_geolocation_dataset.csv')
geolocation_df.head(5)
# Out:
#    geolocation_zip_code_prefix  geolocation_lat  geolocation_lng  \
# 0                         1037       -23.545621       -46.639292
# 1                         1046       -23.546081       -46.644820
# 2                         1046       -23.546129       -46.642951
# 3                         1041       -23.544392       -46.639499
# 4                         1035       -23.541578       -46.641607
#
#   geolocation_city geolocation_state
# 0        sao paulo                SP
# 1        sao paulo                SP
# 2        sao paulo                SP
# 3        sao paulo                SP
# 4        sao paulo                SP

# %%
order_items_df = pd.read_csv('/content/olist_order_items_dataset.csv')
order_items_df.tail(5)
# Out:
#                                 order_id  order_item_id  \
# 112645  fffc94f6ce00a00581880bf54a75a037              1
# 112646  fffcd46ef2263f404302a634eb57f7eb              1
# 112647  fffce4705a9662cd70adb13d4a31832d              1
# 112648  fffe18544ffabc95dfada21779c9644f              1
# 112649  fffe41c64501cc87c801fd61db3f6244              1
#
#                               product_id                         seller_id  \
# 112645  4aa6014eceb682077f9dc4bffebc05b0  b8bc237ba3788b23da09c0f1f3a3288c
# 112646  32e07fd915822b0765e448c4dd74c828  f3c38ab652836d21de61fb8314b69182
# 112647  72a30483855e2eafc67aee5dc2560482  c3cfdc648177fdbbbb35635a37472c53
# 112648  9c422a519119dcad7575db5af1ba540e  2b3e4a2a3ea8e01938cabda2a3e5cc79
# 112649  350688d9dc1e75ff97be326363655e01  f7ccf836d21b2fb1de37564105216cc1
#
#         shipping_limit_date   price  freight_value
# 112645  2018-05-02 04:11:01  299.99          43.41
# 112646  2018-07-20 04:31:48  350.00          36.53
# ...

# %%
payments_df = pd.read_csv('/content/olist_order_payments_dataset.csv')
payments_df.head(5)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value
# 0                     8          99.33
# 1                     1          24.39
# 2                     1          65.71
# 3                     8         107.78
# 4                     2         128.45

# %%
reviews_df = pd.read_csv('/content/olist_order_reviews_dataset.csv')
reviews_df.head(5)
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# ...

# %%
average_rate= reviews_df["review_score"].mean()
average_rate
# Out:
# 4.07089

# %%
orders_df = pd.read_csv('/content/olist_orders_dataset.csv')
orders_df.head(5)
# Out:
#                            order_id                       customer_id  \
# 0  e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1  53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2  47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3  949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4  ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
#
#   order_status order_purchase_timestamp    order_approved_at  \
# 0    delivered      2017-10-02 10:56:33  2017-10-02 11:07:15
# 1    delivered      2018-07-24 20:41:37  2018-07-26 03:24:27
# 2    delivered      2018-08-08 08:38:49  2018-08-08 08:55:23
# 3    delivered      2017-11-18 19:28:06  2017-11-18 19:45:59
# 4    delivered      2018-02-13 21:18:39  2018-02-13 22:20:29
#
#   order_delivered_carrier_date order_delivered_customer_date  \
# 0          2017-10-04 19:55:00           2017-10-10 21:25:13
# ...

# %%
products_df = pd. read_csv('/content/olist_products_dataset.csv')
products_df.head(5)
# Out:
#                          product_id  product_category_name  \
# 0  1e9e8ef04dbcff4541ed26657ea517e5             perfumaria
# 1  3aa071139cb16b67ca9e5dea641aaa2f                  artes
# 2  96bd76ec8810374ed1b65e291975717f          esporte_lazer
# 3  cef67bcfe19066a932b7673e239eb23d                  bebes
# 4  9dc1a7de274444849c219cff195d0b71  utilidades_domesticas
#
#    product_name_lenght  product_description_lenght  product_photos_qty  \
# 0                 40.0                       287.0                 1.0
# 1                 44.0                       276.0                 1.0
# 2                 46.0                       250.0                 1.0
# 3                 27.0                       261.0                 1.0
# 4                 37.0                       402.0                 4.0
#
#    product_weight_g  product_length_cm  product_height_cm  product_width_cm
# 0             225.0               16.0               10.0              14.0
# ...

# %%
sellers_df = pd.read_csv('/content/olist_sellers_dataset.csv')
sellers_df.head(5)
# Out:
#                           seller_id  seller_zip_code_prefix  \
# 0  3442f8959a84dea7ee197c632cb2df15                   13023
# 1  d1b65fc7debc3361ea86b5f14c68d2e2                   13844
# 2  ce3ad9de960102d0677a81f5d0bb7b2d                   20031
# 3  c0f3eea2e14555b6faeea3dd58c1b1c3                    4195
# 4  51a04a8a6bdcb23deccc82b0b80742cf                   12914
#
#          seller_city seller_state
# 0           campinas           SP
# 1         mogi guacu           SP
# 2     rio de janeiro           RJ
# 3          sao paulo           SP
# 4  braganca paulista           SP

# %% [markdown]
# ## Exploratory Data Analysis

# %%
customer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 5 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   customer_id               99441 non-null  object
#  1   customer_unique_id        99441 non-null  object
#  2   customer_zip_code_prefix  99441 non-null  int64
#  3   customer_city             99441 non-null  object
#  4   customer_state            99441 non-null  object
# dtypes: int64(1), object(4)
# memory usage: 3.8+ MB

# %%
geolocation_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000163 entries, 0 to 1000162
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   geolocation_zip_code_prefix  1000163 non-null  int64
#  1   geolocation_lat              1000163 non-null  float64
#  2   geolocation_lng              1000163 non-null  float64
#  3   geolocation_city             1000163 non-null  object
#  4   geolocation_state            1000163 non-null  object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 38.2+ MB

# %%
order_items_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112650 entries, 0 to 112649
# Data columns (total 7 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   order_id             112650 non-null  object
#  1   order_item_id        112650 non-null  int64
#  2   product_id           112650 non-null  object
#  3   seller_id            112650 non-null  object
#  4   shipping_limit_date  112650 non-null  object
#  5   price                112650 non-null  float64
#  6   freight_value        112650 non-null  float64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 6.0+ MB

# %%
payments_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103886 entries, 0 to 103885
# Data columns (total 5 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   order_id              103886 non-null  object
#  1   payment_sequential    103886 non-null  int64
#  2   payment_type          103886 non-null  object
#  3   payment_installments  103886 non-null  int64
#  4   payment_value         103886 non-null  float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 4.0+ MB

# %%
reviews_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   review_id                100000 non-null  object
#  1   order_id                 100000 non-null  object
#  2   review_score             100000 non-null  int64
#  3   review_comment_title     11715 non-null   object
#  4   review_comment_message   41753 non-null   object
#  5   review_creation_date     100000 non-null  object
#  6   review_answer_timestamp  100000 non-null  object
# dtypes: int64(1), object(6)
# memory usage: 5.3+ MB

# %%
orders_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99441 entries, 0 to 99440
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   order_id                       99441 non-null  object
#  1   customer_id                    99441 non-null  object
#  2   order_status                   99441 non-null  object
#  3   order_purchase_timestamp       99441 non-null  object
#  4   order_approved_at              99281 non-null  object
#  5   order_delivered_carrier_date   97658 non-null  object
#  6   order_delivered_customer_date  96476 non-null  object
#  7   order_estimated_delivery_date  99441 non-null  object
# dtypes: object(8)
# memory usage: 6.1+ MB

# %%
products_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32951 entries, 0 to 32950
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   product_id                  32951 non-null  object
#  1   product_category_name       32341 non-null  object
#  2   product_name_lenght         32341 non-null  float64
#  3   product_description_lenght  32341 non-null  float64
#  4   product_photos_qty          32341 non-null  float64
#  5   product_weight_g            32949 non-null  float64
#  6   product_length_cm           32949 non-null  float64
#  7   product_height_cm           32949 non-null  float64
#  8   product_width_cm            32949 non-null  float64
# dtypes: float64(7), object(2)
# memory usage: 2.3+ MB

# %%
sellers_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3095 entries, 0 to 3094
# Data columns (total 4 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   seller_id               3095 non-null   object
#  1   seller_zip_code_prefix  3095 non-null   int64
#  2   seller_city             3095 non-null   object
#  3   seller_state            3095 non-null   object
# dtypes: int64(1), object(3)
# memory usage: 96.8+ KB

# %% [markdown]
# Many of the datasets do not have null values but some do have.

# %%
datasets = [customer_df, geolocation_df, order_items_df, payments_df, reviews_df, orders_df, products_df, sellers_df, category_translation_df]
titles = ["customers", "geolocation", "items", "payments", "reviews", "orders", "products", "sellers", "category_translation"]

data_summary = pd.DataFrame({},)
data_summary['datasets']= titles
data_summary['columns'] = [', '.join([col for col in data.columns ]) for data in datasets]
data_summary['total_rows']= [data.shape[0] for data in datasets]
data_summary['total_cols']= [data.shape[1] for data in datasets]
data_summary['total_duplicate']= [data.duplicated().sum() for data in datasets]
data_summary['total_null']= [data.isnull().sum().sum() for data in datasets]
data_summary['null_cols'] = [', '.join([col for col, null in data.isnull().sum().items() if null > 0]) for data in datasets]
data_summary.style.background_gradient(cmap='YlGnBu')
# Out:
# <style type="text/css">
# #T_45c45_row0_col2, #T_45c45_row4_col2, #T_45c45_row5_col2 {
#   background-color: #f1fabb;
#   color: #000000;
# }
# #T_45c45_row0_col3, #T_45c45_row1_col3, #T_45c45_row3_col3 {
#   background-color: #d6efb3;
#   color: #000000;
# }
# #T_45c45_row0_col4, #T_45c45_row0_col5, #T_45c45_row1_col5, #T_45c45_row2_col4, #T_45c45_row2_col5, #T_45c45_row3_col4, #T_45c45_row3_col5, #T_45c45_row4_col4, #T_45c45_row5_col4, #T_45c45_row6_col4, #T_45c45_row7_col2, #T_45c45_row7_col3, #T_45c45_row7_col4, #T_45c45_row7_col5, #T_45c45_row8_col4 {
#   background-color: #ffffd9;
#   color: #000000;
# }
# #T_45c45_row1_col2, #T_45c45_row1_col4, #T_45c45_row4_col5, #T_45c45_row6_col3, #T_45c45_row8_col3 {
#   background-color: #081d58;
#   color: #f1f1f1;
# }
# #T_45c45_row2_col2 {
#   background-color: #eff9b6;
#   color: #000000;
# }
# #T_45c45_row2_col3, #T_45c45_row4_col3 {
#   background-color: #2498c1;
#   color: #f1f1f1;
# }
# #T_45c45_row3_col2 {
# ...

# %%
for i in datasets:
    i.dropna(inplace=True)

# %%
revenue_df= pd.merge(payments_df, orders_df, on = "order_id")
revenue_df.head(5)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value                       customer_id  \
# 0                     8          99.33  0a8556ac6be836b46b3e89920d59291c
# 1                     1          24.39  f2c7fc58a9de810828715166c672f10a
# 2                     1          65.71  25b14b69de0b6e184ae6fe2755e478f9
# 3                     8         107.78  7a5d8efaaa1081f800628c30d2b0728f
# 4                     2         128.45  15fd6fb8f8312dbb4674e4518d6fa3b3
#
#   order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
revenue_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100739 entries, 0 to 100738
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count   Dtype
# ---  ------                         --------------   -----
#  0   order_id                       100739 non-null  object
#  1   payment_sequential             100739 non-null  int64
#  2   payment_type                   100739 non-null  object
#  3   payment_installments           100739 non-null  int64
#  4   payment_value                  100739 non-null  float64
#  5   customer_id                    100739 non-null  object
#  6   order_status                   100739 non-null  object
#  7   order_purchase_timestamp       100739 non-null  object
#  8   order_approved_at              100739 non-null  object
#  9   order_delivered_carrier_date   100739 non-null  object
#  10  order_delivered_customer_date  100739 non-null  object
#  11  order_estimated_delivery_date  100739 non-null  object
# ...

# %%
import plotly.express as px

# %%
def barplot_visualization(x):
  fig = plt.Figure(figsize = (12, 6))
  fig = px.bar(x = revenue_df[x].value_counts().index, y = revenue_df[x].value_counts(), color = revenue_df[x].value_counts().index, height = 600)
  fig.show()

# %%
barplot_visualization("payment_type")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# It turns out most people prefer using credit cards.

# %%
barplot_visualization("order_status")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Most orders were delivered.

# %% [markdown]
# Let's check the data types to determine the data type of the date and change it if necessary.

# %%
revenue_df.dtypes
# Out:
# order_id                          object
# payment_sequential                 int64
# payment_type                      object
# payment_installments               int64
# payment_value                    float64
# customer_id                       object
# order_status                      object
# order_purchase_timestamp          object
# order_approved_at                 object
# order_delivered_carrier_date      object
# order_delivered_customer_date     object
# order_estimated_delivery_date     object
# dtype: object

# %%
revenue_df["order_purchase_timestamp"] = pd.to_datetime(revenue_df["order_purchase_timestamp"])

# %%
revenue_df.dtypes
# Out:
# order_id                                 object
# payment_sequential                        int64
# payment_type                             object
# payment_installments                      int64
# payment_value                           float64
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                        object
# order_delivered_carrier_date             object
# order_delivered_customer_date            object
# order_estimated_delivery_date            object
# dtype: object

# %%
revenue_df.head(5)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value                       customer_id  \
# 0                     8          99.33  0a8556ac6be836b46b3e89920d59291c
# 1                     1          24.39  f2c7fc58a9de810828715166c672f10a
# 2                     1          65.71  25b14b69de0b6e184ae6fe2755e478f9
# 3                     8         107.78  7a5d8efaaa1081f800628c30d2b0728f
# 4                     2         128.45  15fd6fb8f8312dbb4674e4518d6fa3b3
#
#   order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
revenue_df["order_approved_at"] = pd.to_datetime(revenue_df["order_approved_at"])
revenue_df["order_delivered_carrier_date"] = pd.to_datetime(revenue_df["order_delivered_carrier_date"])
revenue_df["order_delivered_customer_date"] = pd.to_datetime(revenue_df["order_delivered_customer_date"])
revenue_df["order_estimated_delivery_date"] = pd.to_datetime(revenue_df["order_estimated_delivery_date"])

# %%
revenue_df.dtypes
# Out:
# order_id                                 object
# payment_sequential                        int64
# payment_type                             object
# payment_installments                      int64
# payment_value                           float64
# customer_id                              object
# order_status                             object
# order_purchase_timestamp         datetime64[ns]
# order_approved_at                datetime64[ns]
# order_delivered_carrier_date     datetime64[ns]
# order_delivered_customer_date    datetime64[ns]
# order_estimated_delivery_date    datetime64[ns]
# dtype: object

# %%
revenue_df.head(5)
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value                       customer_id  \
# 0                     8          99.33  0a8556ac6be836b46b3e89920d59291c
# 1                     1          24.39  f2c7fc58a9de810828715166c672f10a
# 2                     1          65.71  25b14b69de0b6e184ae6fe2755e478f9
# 3                     8         107.78  7a5d8efaaa1081f800628c30d2b0728f
# 4                     2         128.45  15fd6fb8f8312dbb4674e4518d6fa3b3
#
#   order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
revenue_df["order_delivered_customer_date"].min(), revenue_df["order_delivered_customer_date"].max()
# Out:
# (Timestamp('2016-10-11 13:46:32'), Timestamp('2018-10-17 13:22:46'))

# %%
revenue_df["order_approved_at"].min(), revenue_df["order_approved_at"].max()
# Out:
# (Timestamp('2016-10-04 09:43:32'), Timestamp('2018-08-29 15:10:26'))

# %%
revenue_df["order_approved_at"].max() - revenue_df["order_approved_at"].min()
# Out:
# Timedelta('694 days 05:26:54')

# %%
revenue_df["month"] = revenue_df["order_approved_at"].dt.month

# %%
revenue_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value                       customer_id  \
# 0                     8          99.33  0a8556ac6be836b46b3e89920d59291c
# 1                     1          24.39  f2c7fc58a9de810828715166c672f10a
# 2                     1          65.71  25b14b69de0b6e184ae6fe2755e478f9
# 3                     8         107.78  7a5d8efaaa1081f800628c30d2b0728f
# 4                     2         128.45  15fd6fb8f8312dbb4674e4518d6fa3b3
#
#   order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
#revenue_df['month'] = revenue_df.replace(['1','2','3','4','5'], ['January','February','March','April','May'])
#replace monthid with actual name of the month
revenue_df['month'] = revenue_df['month'].replace([1,2,3,4,5,6,7],['January','February','March','April','May','June','July'])

# %%
revenue_df['month'] = revenue_df['month'].replace([8,9,10,11,12],['August','September','October','November','December'])

# %%
revenue_df.head()
# Out:
#                            order_id  payment_sequential payment_type  \
# 0  b81ef226f3fe1789b1e8b2acac839d17                   1  credit_card
# 1  a9810da82917af2d9aefd1278f1dcfa0                   1  credit_card
# 2  25e8ea4e93396b6fa0d3dd708e76c1bd                   1  credit_card
# 3  ba78997921bbcdc1373bb41e913ab953                   1  credit_card
# 4  42fdf880ba16b47b59251dd489d4441a                   1  credit_card
#
#    payment_installments  payment_value                       customer_id  \
# 0                     8          99.33  0a8556ac6be836b46b3e89920d59291c
# 1                     1          24.39  f2c7fc58a9de810828715166c672f10a
# 2                     1          65.71  25b14b69de0b6e184ae6fe2755e478f9
# 3                     8         107.78  7a5d8efaaa1081f800628c30d2b0728f
# 4                     2         128.45  15fd6fb8f8312dbb4674e4518d6fa3b3
#
#   order_status order_purchase_timestamp   order_approved_at  \
# ...

# %%
#df.loc[df['column name'] condition, 'new column name'] = 'value if condition is met'
revenue_df.loc [revenue_df['month']. January 'Quarter'] = 'Quarter 1'
#revenue_df.loc[revenue_df['month'] condition, 'April'or 'May' or 'June'] = 'Quarter 2'
#revenue_df.loc[revenue_df['month'] condition, 'July'or 'August' or 'September'] = 'Quarter 3'
#revenue_df.loc[revenue_df['month'] condition, 'January'or 'February' or 'March'] = 'Quarter 1'
# Out:
#   File "<ipython-input-43-7f36e1d4f73a>", line 2
#     revenue_df.loc [revenue_df['month']. January 'Quarter'] = 'Quarter 1'
#                     ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
revenue_df['quarter'] = pd.PeriodIndex(revenue_df.order_approved_at, freq='Q')

# %%
revenue_df.head()

# %%
revenue_df.drop('Quarter', inplace=True, axis=1)

# %%
revenue_df.head()

# %%
sum_by_month = revenue_df.groupby("month")["payment_value"].count()
sum_by_month

# %%
revenue_df.set_index('order_approved_at', inplace=True)
revenue_df['payment_value'].plot()

# %%
revenue_df.set_index('order_delivered_customer_date', inplace=True)
revenue_df['payment_value'].plot()

# %%
revenue_df.head()

# %%
fig, axs = plt.subplots(figsize=(12, 4))
revenue_df.groupby(revenue_df['order_delivered_customer_date'].dt.month)['payment_value'].mean().plot(kind='bar', rot=0, ax=axs)

# %%
revenue_df.set_index('order_delivered_customer_date	', inplace=True)
revenue_df.groupby('month')['payment_value'].plot(legend=True)

# %%
revenue_df.groupby('payment_value')['month'].plot(legend=True)

# %%
def barplot_visualization(x):
  fig = plt.Figure(figsize = (12, 6))
  fig = px.bar(x = revenue_df[x].value_counts().index, y = revenue_df[x].value_counts(), revenue_df[x].value_counts().index, height = 600)
  fig.show()

# %%
df.set_index('Date', inplace=True)
df['adj_close'].plot()

# %%
revenue_df['Quarter'] = revenue_df['month'].apply(func)

# %%
revenue_df.head()

# %%
revenue_df['Quarter'] = revenue_df['month'].apply(lambda x: 'Quarter One' if 'January', 'February','March' else 'value if condition is not met')

# %%
Total_Revenue= revenue_df['payment_value'].sum()
print(Total_Revenue)

# %% [markdown]
# The total revenue made on Olist is $15,419,682.85

# %%
  #print(pd.unique(revenue_df['order_id']))
  revenue_df['order_id'].nunique()

# %% [markdown]
# There were 96,460 orders made on Olist.

# %%
revenue2df = revenue_df.copy

# %%
revenue_df.head(5)

# %%
sns.set(rc={'figure.figsize':(11, 4)})

# %%
df_new = revenue_df[['payment_value', 'order_approved_at']]
df_new.head(5)

# %%
sns.lineplot(df_new['order_approved_at'])

# %%
sns.lineplot(df_new)

# %%
revenue_df['order_purchase_timestamp'].plot(linewidth=0.5);

# %%
sns.lineplot(revenue_df['payment_value'])

# %%
ax = revenue_df['2016', 'order_purchase_timestamp'].plot()
ax.set_ylabel('Daily Consumption (GWh)');

# %%
revenue_df['date'] = revenue_df['order_purchase_timestamp'].dt.date
revenue_df['date'] = revenue_df['order_purchase_timestamp'].dt.date

# %%
revenue_df.head(5)

# %%
revenue_df['Year'] = revenue_df.index.year
revenue_df['Month'] = revenue_df.index.month
revenue_df['Weekday Name'] = revenue_df.index.weekday_name
# Display a random sampling of 5 rows
revenue_df.sample(5, random_state=0)

# %%
revenue_df= pd.merge(payments_df, orders_df, on = "order_id")
revenue_df.head(5)

# %%
plt.figure(figsize=(8, 6))
sns.countplot(x='order_status', data=df_train, palette='Blues_r')
plt.title('Distribution of Order Statuses', fontsize=16)
plt.xlabel('Order Status', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)
sns.despine()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(revenue_df['order_purchase_timestamp'], bins=50, kde=False, color='royalblue')
plt.title('Distribution of Order Purchase Timestamps', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)
sns.despine()
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.histplot(revenue_df['order_approved_at'], bins=50, kde=False, color='royalblue')
plt.title('Distribution of Order Approval Timestamps', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)
sns.despine()
plt.show()

# %%
seller_data= pd.merge(sellers_df, order_items_df, on = "seller_id")
seller_data.head (5)

# %%
plt.figure(figsize=(10, 6))
sns.histplot(seller_data['shipping_limit_date'], bins=50, kde=False, color='royalblue')
plt.title('Distribution of Order Approval Timestamps', fontsize=16)
plt.xlabel('Date', fontsize=14)
plt.ylabel('Count', fontsize=14)
plt.tick_params(axis='both', which='major', labelsize=12)
sns.despine()
plt.show()
